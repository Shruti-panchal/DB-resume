# %%
pip install resume-parser
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyresparser
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spaCy v2.1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement v2.1 (from versions: none)
# ERROR: No matching distribution found for v2.1

# %%
from pyresparser import ResumeParser
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
data = ResumeParser('Resume(2) (1) (1).pdf').get_extracted_data()
# Out:
# C:\Users\DeLL\anaconda3\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.9). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
for key, value in data.items():
    print(f"{key}: {value}")
# Out:
# name: Shruti Panchal
# email: spanchal1412@gmail.com
# mobile_number: 5393032
# skills: ['Email', 'Pycharm', 'Engineering', 'Sql', 'C', 'Programming', 'Database', 'Scrum', 'Html', 'Ui', 'Website', 'Flask', 'Css', 'Python', 'Agile', 'Computer science', 'Machine learning', 'Django', 'Algorithms', 'Javascript']
# college_name: None
# degree: None
# designation: None
# experience: None
# company_names: None
# no_of_pages: 2
# total_experience: 0

# %%
# res_pdf = ResumeParser('res.pdf').get_extracted_data()
# res_pdf

# %%
res = pd.read_csv("216done - UpdatedResumeDataSet.csv.csv")

# %%
res['Resume'].to_csv("resume.csv", sep=',', index=False, encoding='utf-8')
resume = res[['Category', 'Resume']]
resume
# Out:
#          Category                                             Resume
# 0    Data Science  Education Details \n\nData Science Assurance A...
# 1    Data Science  Education Details \nMay 2013 to May 2017 B.E  ...
# 2    Data Science  Areas of Interest Deep Learning, Control Syste...
# 3    Data Science  Skills : R, Python, SAP, HANA, Tableau, SAP HA...
# 4    Data Science  Education Details \n MCA   YMCAUST,  Faridabad...
# ..            ...                                                ...
# 573       Testing  Computer Skills: â¢ Proficient in MS office (...
# 574       Testing  â Willingness to accept the challenges. â ...
# 575       Testing  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...
# 576       Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 577       Testing  Skill Set OS Windows XP/7/8/8.1/10 Database MY...
#
# [578 rows x 2 columns]

# %%
# fig, ax = plt.subplots(figsize=(12,4))
# ax.axis('tight')
# ax.axis('off')

# %%
# the_table = ax.table(cellText=resume.values, colLabels=resume.columns, loc='center')

# %%
# plt.savefig("foo.pdf", bbox_inches='tight', format='pdf')

# %%
# plt.close(fig)

# %%
for index, row in resume.iterrows():
    print(row, '\n')
# Out:
# Category                                         Data Science
# Resume      Education Details \n\nData Science Assurance A...
# Name: 0, dtype: object
#
# Category                                         Data Science
# Resume      Education Details \nMay 2013 to May 2017 B.E  ...
# Name: 1, dtype: object
#
# Category                                         Data Science
# Resume      Areas of Interest Deep Learning, Control Syste...
# Name: 2, dtype: object
#
# Category                                         Data Science
# Resume      Skills : R, Python, SAP, HANA, Tableau, SAP HA...
# Name: 3, dtype: object
#
# Category                                         Data Science
# Resume      Education Details \n MCA   YMCAUST,  Faridabad...
# Name: 4, dtype: object
#
# Category                                         Data Science
# Resume      SKILLS C Basics, IOT, Python, MATLAB, Data Sci...
# Name: 5, dtype: object
#
# Category                                         Data Science
# ...

# %%
pip install pdfkit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfkit as pdf
import sqlite3

# %%
wkhtmltopdf_path = r'C:\\Users\\DeLL\\wkhtmltopdf\\bin\\wkhtmltopdf.exe'

# %%
for index, row in resume.iterrows():
    resco = row['Resume']
    resume[index].to_html(f'{index}.html', index=False)
    
    topdf = f"{index}.pdf"
    pdf.from_file(f'{index}.html', topdf, configuration=pdf.configuration(wkhtmltopdf=wkhtmltopdf_path))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
resume.to_html('res_html.html', index=False)
html = pd.read_html("res_html.html")
html

# %%
wkhtmltopdf_path = r'C:\\Users\\DeLL\\wkhtmltopdf\\bin\\wkhtmltopdf.exe'

# %%
topdf = "h2p.pdf"

# %%
pdf.from_file('res_html.html', topdf, configuration=pdf.configuration(wkhtmltopdf=wkhtmltopdf_path))
